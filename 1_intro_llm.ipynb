# %% [markdown]
# ## Intro to Large Language Models

# %% [markdown]
# Activate GPU in Colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/JavierPachas/llm_projects/blob/main/1_intro_llm.ipynb)

# %%
# %%capture
% !pip install transformers==4.41.2 accelerate==0.31.0

# %% [markdown]
# ### Phi-3

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load model and tokenizer
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map = "cuda",
    dtype = "auto",
    trust_remote_code = False,
)

tokenizer = AutoTokenizer.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]

# %% [markdown]
# Instead of using the model and tokenizer directly, we can wrap them in a pipeline

# %%
from transformers import pipeline

# Create a pipeline
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=512, 
    do_sample=False
)
# Out:
# Device set to use cuda
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.

# %%
# The prompt (user input/ query)
messages = [
    {"role": "user", "content": "Explain the theory of relativity in simple terms."}
]

# Generate output
output = generator(messages)
print(output[0]['generated_text'])
# Out:
#  The theory of relativity, developed by Albert Einstein, fundamentally changed our understanding of space, time, and gravity. It consists of two parts: special relativity and general relativity.
#
#
# Special relativity, introduced in 1905, deals with objects moving at constant speeds, particularly those approaching the speed of light. It tells us that time and space are not absolute but relative to the observer's motion. One of the most famous outcomes of special relativity is the equation E=mc², which shows that energy (E) and mass (m) are interchangeable; they are different forms of the same thing.
#
#
# General relativity, published in 1915, expands on this by including gravity. It describes gravity not as a force between masses, as Newton did, but as a curvature of spacetime caused by mass and energy. Massive objects like stars and planets warp the fabric of spacetime around them, and this curvature guides the motion of objects, which we perceive as the force of gravity.
#
#
# In simple terms, imagine spacetime as a trampoline. If you place a heavy ball in the middle, it will create a dip. Smaller balls will roll towards the heavier one, not because they are being pulled by a force, but because they are following the curved path in the trampoline. That's how general relativity explains gravity.
